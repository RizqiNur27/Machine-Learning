# %% [markdown]
# # Muhammad Rizqi Nurrohmat - 0110224001
# # Machine Learning - Latihan 2 - Algoritma KNN

# %% [markdown]
# ## ***IMPORT LIBRARY***

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## ***DATASET***

# %%
data = {
    'NIM' : ['TI001', 'TI002', 'TI003', 'TI004', 'TI005', 'TI006', 'TI007', 'TI008', 'TI009', 'TI010'],
    'Sebenarnya' : ['Lulus', 'Lulus', 'Lulus', 'Lulus', 'Lulus', 'Tidak Lulus', 'Tidak Lulus', 'Tidak Lulus', 'Tidak Lulus', 'Tidak Lulus'],
    'Prediksi' : ['Lulus', 'Lulus', 'Lulus', 'Tidak Lulus', 'Tidak Lulus', 'Lulus', 'Tidak Lulus', 'Tidak Lulus', 'Tidak Lulus', 'Tidak Lulus']
}

df = pd.DataFrame(data)

# simpan data ke file.csv
df.to_csv('../data/data_latihan2.csv', index=False)

df
# Out:
#      NIM   Sebenarnya     Prediksi
# 0  TI001        Lulus        Lulus
# 1  TI002        Lulus        Lulus
# 2  TI003        Lulus        Lulus
# 3  TI004        Lulus  Tidak Lulus
# 4  TI005        Lulus  Tidak Lulus
# 5  TI006  Tidak Lulus        Lulus
# 6  TI007  Tidak Lulus  Tidak Lulus
# 7  TI008  Tidak Lulus  Tidak Lulus
# 8  TI009  Tidak Lulus  Tidak Lulus
# 9  TI010  Tidak Lulus  Tidak Lulus

# %% [markdown]
# ## ***Konversi Label ke Bentuk Numerik***

# %%
# Konversi label ke bentuk numerik
df['label_true'] = df['Sebenarnya'].map({'Lulus': 1, 'Tidak Lulus': 0})
df['label_pred'] = df['Prediksi'].map({'Lulus': 1, 'Tidak Lulus': 0})

y_true = df['label_true']
y_pred = df['label_pred']

# %% [markdown]
# ## ***Confussion Matrix***

# %%
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Tidak Lulus', 'Lulus'], yticklabels=['Tidak Lulus', 'Lulus'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
#  [[4 1]
#  [2 3]]

# %% [markdown]
# ## ***Metrics***

# %%
print("Accuracy:", accuracy_score(y_true, y_pred) * 100, "%")
print("Precision:", precision_score(y_true, y_pred) * 100, "%")
print("Recall:", recall_score(y_true, y_pred) * 100, "%")
# Out:
# Accuracy: 70.0 %
# Precision: 75.0 %
# Recall: 60.0 %

# %% [markdown]
# # **LATIHAN 2**

# %% [markdown]
# 1. Buat tabel confusion matrix berdasarkan tabel diatas
# 2. Hitung nilai persentase dari: accuracy, precision dan recall
#
# JAWABAN
#
# (1)
# ![image.png](attachment:image.png)
#
# (2)
# Accuracy: 70.0 %
# Precision: 75.0 %
# Recall: 60.0 %
